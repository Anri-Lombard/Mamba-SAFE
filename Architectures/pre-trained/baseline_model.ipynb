# %%
# !pip install torch torchvision torchaudio
# !pip install rdkit-pypi
# !pip install transformers
# !pip install datasets
# !pip install safe-mol
# !pip install molfeat
# Out:
# Requirement already satisfied: torch in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.2.0)
# Requirement already satisfied: torchvision in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.17.0)
# Requirement already satisfied: torchaudio in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.2.0)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch) (2024.2.0)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->torchvision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->torchvision) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->torchvision) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: rdkit-pypi in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2022.9.5)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from rdkit-pypi) (1.26.4)
# Requirement already satisfied: Pillow in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from rdkit-pypi) (10.2.0)
# Requirement already satisfied: transformers in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (4.37.2)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2024.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->transformers) (2023.11.17)
# Requirement already satisfied: datasets in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.17.1)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (2.2.0)
# Requirement already satisfied: requests>=2.19.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (0.70.16)
# Collecting fsspec<=2023.10.0,>=2023.1.0 (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets)
#   Using cached fsspec-2023.10.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: aiohttp in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (0.20.3)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from huggingface-hub>=0.19.4->datasets) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Using cached fsspec-2023.10.0-py3-none-any.whl (166 kB)
# Installing collected packages: fsspec
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.2.0
#     Uninstalling fsspec-2024.2.0:
#       Successfully uninstalled fsspec-2024.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# s3fs 2024.2.0 requires fsspec==2024.2.0, but you have fsspec 2023.10.0 which is incompatible.
# gcsfs 2024.2.0 requires fsspec==2024.2.0, but you have fsspec 2023.10.0 which is incompatible.
# Successfully installed fsspec-2023.10.0
# Requirement already satisfied: safe-mol in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.1.5)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from safe-mol) (4.66.1)
# Requirement already satisfied: loguru in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from safe-mol) (0.7.2)
# Requirement already satisfied: typer in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from safe-mol) (0.9.0)
# Requirement already satisfied: universal-pathlib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from safe-mol) (0.2.1)
# Requirement already satisfied: datamol in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from safe-mol) (0.12.4)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from safe-mol) (1.26.4)
# Requirement already satisfied: torch>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from safe-mol) (2.2.0)
# Requirement already satisfied: transformers in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from safe-mol) (4.37.2)
# Requirement already satisfied: datasets in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from safe-mol) (2.17.1)
# Requirement already satisfied: tokenizers in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from safe-mol) (0.15.2)
# Requirement already satisfied: accelerate in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from safe-mol) (0.27.2)
# Requirement already satisfied: evaluate in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from safe-mol) (0.4.1)
# Requirement already satisfied: wandb in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from safe-mol) (0.16.3)
# Requirement already satisfied: huggingface-hub in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from safe-mol) (0.20.3)
# Requirement already satisfied: rdkit in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from safe-mol) (2023.9.5)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch>=2.0->safe-mol) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch>=2.0->safe-mol) (4.9.0)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch>=2.0->safe-mol) (1.12)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch>=2.0->safe-mol) (3.2.1)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch>=2.0->safe-mol) (3.1.3)
# Requirement already satisfied: fsspec in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch>=2.0->safe-mol) (2023.10.0)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from accelerate->safe-mol) (23.2)
# Requirement already satisfied: psutil in /Users/anrilombard/Library/Python/3.11/lib/python/site-packages (from accelerate->safe-mol) (5.9.8)
# Requirement already satisfied: pyyaml in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from accelerate->safe-mol) (6.0.1)
# Requirement already satisfied: safetensors>=0.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from accelerate->safe-mol) (0.4.2)
# Requirement already satisfied: joblib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datamol->safe-mol) (1.3.2)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datamol->safe-mol) (2.2.0)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datamol->safe-mol) (1.12.0)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datamol->safe-mol) (3.8.2)
# Requirement already satisfied: pillow in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datamol->safe-mol) (10.2.0)
# Requirement already satisfied: selfies in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datamol->safe-mol) (2.1.1)
# Requirement already satisfied: platformdirs in /Users/anrilombard/Library/Python/3.11/lib/python/site-packages (from datamol->safe-mol) (4.1.0)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datamol->safe-mol) (1.4.0)
# Requirement already satisfied: importlib-resources in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datamol->safe-mol) (6.1.1)
# Requirement already satisfied: pyarrow>=12.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets->safe-mol) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets->safe-mol) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets->safe-mol) (0.3.8)
# Requirement already satisfied: requests>=2.19.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets->safe-mol) (2.31.0)
# Requirement already satisfied: xxhash in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets->safe-mol) (3.4.1)
# Requirement already satisfied: multiprocess in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets->safe-mol) (0.70.16)
# Requirement already satisfied: aiohttp in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets->safe-mol) (3.9.3)
# Requirement already satisfied: responses<0.19 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from evaluate->safe-mol) (0.18.0)
# Requirement already satisfied: regex!=2019.12.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from transformers->safe-mol) (2023.12.25)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from typer->safe-mol) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from wandb->safe-mol) (3.1.42)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from wandb->safe-mol) (1.40.6)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from wandb->safe-mol) (0.4.0)
# Requirement already satisfied: setproctitle in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from wandb->safe-mol) (1.3.3)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from wandb->safe-mol) (68.2.2)
# Requirement already satisfied: appdirs>=1.4.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from wandb->safe-mol) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from wandb->safe-mol) (4.25.2)
# Requirement already satisfied: six>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from docker-pycreds>=0.4.0->wandb->safe-mol) (1.16.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp->datasets->safe-mol) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp->datasets->safe-mol) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp->datasets->safe-mol) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp->datasets->safe-mol) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp->datasets->safe-mol) (1.9.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb->safe-mol) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.19.0->datasets->safe-mol) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.19.0->datasets->safe-mol) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.19.0->datasets->safe-mol) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.19.0->datasets->safe-mol) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2->torch>=2.0->safe-mol) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->datamol->safe-mol) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->datamol->safe-mol) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->datamol->safe-mol) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->datamol->safe-mol) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->datamol->safe-mol) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->datamol->safe-mol) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->datamol->safe-mol) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->datamol->safe-mol) (2023.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn->datamol->safe-mol) (3.2.0)
# Requirement already satisfied: mpmath>=0.19 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from sympy->torch>=2.0->safe-mol) (1.3.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->safe-mol) (5.0.1)
# Requirement already satisfied: molfeat in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.10.0)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from molfeat) (4.66.1)
# Requirement already satisfied: loguru in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from molfeat) (0.7.2)
# Requirement already satisfied: joblib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from molfeat) (1.3.2)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from molfeat) (3.13.1)
# Requirement already satisfied: fsspec>=2021.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from molfeat) (2023.10.0)
# Requirement already satisfied: s3fs>=2021.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from molfeat) (2024.2.0)
# Requirement already satisfied: gcsfs>=2021.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from molfeat) (2024.2.0)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from molfeat) (2.2.0)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from molfeat) (1.26.4)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from molfeat) (1.12.0)
# Requirement already satisfied: torch>=1.13 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from molfeat) (2.2.0)
# Requirement already satisfied: datamol>=0.8.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from molfeat) (0.12.4)
# Requirement already satisfied: pyyaml in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from molfeat) (6.0.1)
# Requirement already satisfied: platformdirs in /Users/anrilombard/Library/Python/3.11/lib/python/site-packages (from molfeat) (4.1.0)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from molfeat) (3.8.2)
# Requirement already satisfied: h5py in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from molfeat) (3.10.0)
# Requirement already satisfied: pyarrow in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from molfeat) (14.0.2)
# Requirement already satisfied: pydantic>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from molfeat) (2.6.1)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from molfeat) (1.4.0)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from molfeat) (23.2)
# Requirement already satisfied: pmapper in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from molfeat) (1.0.4)
# Requirement already satisfied: mordredcommunity in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from molfeat) (2.0.4)
# Requirement already satisfied: python-dotenv in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from molfeat) (1.0.1)
# Requirement already satisfied: rdkit in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from molfeat) (2023.9.5)
# Requirement already satisfied: pillow in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datamol>=0.8.0->molfeat) (10.2.0)
# Requirement already satisfied: selfies in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datamol>=0.8.0->molfeat) (2.1.1)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datamol>=0.8.0->molfeat) (4.9.0)
# Requirement already satisfied: importlib-resources in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datamol>=0.8.0->molfeat) (6.1.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from gcsfs>=2021.9->molfeat) (3.9.3)
# Requirement already satisfied: decorator>4.1.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from gcsfs>=2021.9->molfeat) (4.4.2)
# Collecting fsspec>=2021.9 (from molfeat)
#   Using cached fsspec-2024.2.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: google-auth>=1.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from gcsfs>=2021.9->molfeat) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from gcsfs>=2021.9->molfeat) (1.2.0)
# Requirement already satisfied: google-cloud-storage in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from gcsfs>=2021.9->molfeat) (2.14.0)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from gcsfs>=2021.9->molfeat) (2.31.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic>=2.0.0->molfeat) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic>=2.0.0->molfeat) (2.16.2)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from s3fs>=2021.9->molfeat) (2.11.2)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch>=1.13->molfeat) (1.12)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch>=1.13->molfeat) (3.2.1)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch>=1.13->molfeat) (3.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->molfeat) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->molfeat) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->molfeat) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->molfeat) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->molfeat) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib->molfeat) (2.8.2)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from mordredcommunity->molfeat) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->molfeat) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->molfeat) (2023.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn->molfeat) (3.2.0)
# Requirement already satisfied: botocore<1.34.35,>=1.33.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2021.9->molfeat) (1.34.34)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2021.9->molfeat) (1.14.1)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2021.9->molfeat) (0.11.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2021.9->molfeat) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2021.9->molfeat) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2021.9->molfeat) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2021.9->molfeat) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2021.9->molfeat) (1.9.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-auth>=1.2->gcsfs>=2021.9->molfeat) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-auth>=1.2->gcsfs>=2021.9->molfeat) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-auth>=1.2->gcsfs>=2021.9->molfeat) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-auth-oauthlib->gcsfs>=2021.9->molfeat) (1.3.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-cloud-storage->gcsfs>=2021.9->molfeat) (2.15.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-cloud-storage->gcsfs>=2021.9->molfeat) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-cloud-storage->gcsfs>=2021.9->molfeat) (2.7.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-cloud-storage->gcsfs>=2021.9->molfeat) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->gcsfs>=2021.9->molfeat) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->gcsfs>=2021.9->molfeat) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->gcsfs>=2021.9->molfeat) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->gcsfs>=2021.9->molfeat) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2->torch>=1.13->molfeat) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from sympy->torch>=1.13->molfeat) (1.3.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from botocore<1.34.35,>=1.33.2->aiobotocore<3.0.0,>=2.5.4->s3fs>=2021.9->molfeat) (1.0.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage->gcsfs>=2021.9->molfeat) (1.62.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage->gcsfs>=2021.9->molfeat) (4.25.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs>=2021.9->molfeat) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs>=2021.9->molfeat) (3.2.2)
# Using cached fsspec-2024.2.0-py3-none-any.whl (170 kB)
# Installing collected packages: fsspec
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.10.0
#     Uninstalling fsspec-2023.10.0:
#       Successfully uninstalled fsspec-2023.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 2.17.1 requires fsspec[http]<=2023.10.0,>=2023.1.0, but you have fsspec 2024.2.0 which is incompatible.
# Successfully installed fsspec-2024.2.0

# %%
import pandas as pd
import os

os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
zinc_data_path = './zinc250k.csv'
zinc_df = pd.read_csv(zinc_data_path)

zinc_df.head()
# Out:
#                                               smiles       qed        sa  \
# 0            CC(C)(C)c1ccc2occ(CC(=O)Nc3ccccc3F)c2c1  0.702012  0.879545
# 1       C[C@@H]1CC(Nc2cncc(-c3nncn3C)c2)C[C@@H](C)C1  0.928975  0.729777
# 2  N#Cc1ccc(-c2ccc(O[C@@H](C(=O)N3CCCC3)c3ccccc3)...  0.599682  0.836596
# 3  CCOC(=O)[C@@H]1CCCN(C(=O)c2nc(-c3ccc(C)cc3)n3c...  0.690944  0.797472
# 4  N#CC1=C(SCC(=O)Nc2cccc(Cl)c2)N=C([O-])[C@H](C#...  0.789027  0.662758
#
#    parp1  fa7  5ht1b  braf  jak2
# 0    8.9  7.2    9.4   9.6   8.5
# 1    8.6  7.9    8.6   9.1   8.3
# 2    9.7  7.8   10.1  10.2   8.6
# 3    9.9  7.6    9.9   9.7   9.2
# 4    9.4  7.8    6.3   7.9   8.7

# %% [markdown]
# ## Convert SMILES to SAFE

# %%
import safe as sf
import datamol as dm
# Out:
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality

# %%
celecoxib = zinc_df['smiles'][3]
celecoxib_mol = dm.to_mol(celecoxib)

display(dm.to_image(celecoxib_mol))

# %%
safe_str = sf.encode(celecoxib, canonical=True, slicer='attach')

print(safe_str)
print(f"Representation using {len(safe_str.split('.'))} fragments")
# Out:
# c15nc%16n2c1C%17%30C%14%32C%44%22C%26%13C2%41%12.[C@]1%28%35C7%36N%19C%27%39C%42%33C1%43%31.c1%16c%23c6c9c%38c1%29.C48%18%24.C%40%10%18%20.C%379%11%25.C=%15%28%34.C5%19=%21.O%20%34.O=%15.O=%21.[H]4.[H]%24.[H]8.[H]%10.[H]%40.[H]%35.[H]%43.[H]%31.[H]%42.[H]%33.[H]%39.[H]%27.[H]%29.[H]%38.[H]%25.[H]%11.[H]%37.[H]6.[H]%23.[H]%30.[H]%17.[H]%32.[H]%14.[H]%22.[H]%44.[H]%13.[H]%26.[H]%12.[H]%41.[H]7.[H]%36
# Representation using 42 fragments

# %%
# Add 'safe' column to dataframe and convert smiles to safe
# zinc_df['safe'] = zinc_df['smiles'].apply(lambda x: sf.encode(dm.to_mol(x), canonical=True, slicer='attach'))

# %%
# Use a smaller piece of the dataset for the sake of time
zinc_df_small = zinc_df.head(1000).copy()
zinc_df_small['safe'] = zinc_df_small['smiles'].apply(lambda x: sf.encode(x, canonical=True, slicer='attach'))
zinc_df_small.head()
# Out:
#                                               smiles       qed        sa  \
# 0            CC(C)(C)c1ccc2occ(CC(=O)Nc3ccccc3F)c2c1  0.702012  0.879545
# 1       C[C@@H]1CC(Nc2cncc(-c3nncn3C)c2)C[C@@H](C)C1  0.928975  0.729777
# 2  N#Cc1ccc(-c2ccc(O[C@@H](C(=O)N3CCCC3)c3ccccc3)...  0.599682  0.836596
# 3  CCOC(=O)[C@@H]1CCCN(C(=O)c2nc(-c3ccc(C)cc3)n3c...  0.690944  0.797472
# 4  N#CC1=C(SCC(=O)Nc2cccc(Cl)c2)N=C([O-])[C@H](C#...  0.789027  0.662758
#
#    parp1  fa7  5ht1b  braf  jak2  \
# 0    8.9  7.2    9.4   9.6   8.5
# 1    8.6  7.9    8.6   9.1   8.3
# 2    9.7  7.8   10.1  10.2   8.6
# 3    9.9  7.6    9.9   9.7   9.2
# 4    9.4  7.8    6.3   7.9   8.7
#
#                                                 safe
# 0  c1%20c%31c%17c2oc%14c%30c2c1%11.c1%27c%12c%18c...
# 1  [C@@]14%13C5%12C%26%27C%11%22[C@@]%32%17C1%28%...
# 2  N1%12C%14%22C%13%25C%34%17C16%27.c1%26c8c%18c%...
# 3  c15nc%16n2c1C%17%30C%14%32C%44%22C%26%13C2%41%...
# 4  C1%25=C%27N=C9[C@@]%294C12C%288C%31%20C%30%21C...

# %% [markdown]
# ## Baseline: SAFE-gpt based on gpt2

# %%
designer = sf.SAFEDesign.load_default(verbose=True)

designer.model
# Out:
# SAFEDoubleHeadsModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(1880, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-11): 12 x GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=1880, bias=False)
#   (multiple_choice_head): PropertyHead(
#     (summary): Linear(in_features=768, out_features=64, bias=True)
#     (activation): ReLU()
#     (out): Linear(in_features=64, out_features=1, bias=True)
#   )
# )

# %%
# Take an example molecule from the dataset
# candidate_mol = dm.to_mol(zinc_df_small['smiles'][3])

candidate_smiles = "O=C(C#CCN1CCCCC1)Nc1ccc2ncnc(Nc3cccc(Br)c3)c2c1"
candidate_mol = dm.to_mol(candidate_smiles)

dm.to_image(candidate_mol)

# %% [markdown]
# ## De novo generation - without constraints

# %%
generated_smiles = designer.de_novo_generation(sanitize=True, n_samples_per_trial=400)

generated_smiles[:5]
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Failed to find the pandas get_adjustment() function to patch
# Failed to find the pandas get_adjustment() function to patch
# Failed to find the pandas get_adjustment() function to patch
# Failed to find the pandas get_adjustment() function to patch
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# 2024-03-04 15:45:30.293 | INFO     | safe.sample:de_novo_generation:577 - After sanitization, 378 / 400 (94.50 %) generated molecules are valid !
# ['CC(C)(C)NS(=O)(=O)c1ccc(Cl)c(C(=O)OCC(=O)N2CCCC2)c1',
#  'Cc1cc(C#N)nc(NC[C@H]2CCN(C(=O)[C@H]3COC(=O)N3)C2)n1',
#  'C[C@H]1CCCN(c2cc(-c3nc(CC(=O)NCc4ccccc4)no3)ccn2)C1',
#  'C[C@H](C[C@@H]1CCCO1)NC(=O)N[C@@H](C)c1cnn(Cc2ccccc2)c1',
#  'CC(C)OCCCC(=O)O[C@H](C(=O)NCc1ccccc1)c1ccccc1']

# %%
dm.to_image(generated_smiles[:5], mol_size=(350, 200))

# %%
from rdkit import Chem
from rdkit.Chem import QED

# %%
# Evaluate the quality of the generated molecules
def qed_score(smiles):
    # convert smiles to safe
    safe_str = sf.encode(smiles, canonical=True, slicer='attach')
    # convert safe to mol
    # mol = dm.to_mol(safe_str)
    mol = dm.to_mol(smiles)

    # Calculate the QED score
    qed_score = QED.qed(mol)
    return qed_score

# Calculate the QED score for each molecule
qed_scores = [qed_score(s) for s in generated_smiles]
qed_scores
# Out:
# [0.7618747534959256,
#  0.7984483343359663,
#  0.6945084461891056,
#  0.8001033831445551,
#  0.5111066615718552,
#  0.8665622544755486,
#  0.8183779979980021,
#  0.5697639742621186,
#  0.4642548785646865,
#  0.7586015980414229,
#  0.8576407348785365,
#  0.5960015390813952,
#  0.7544894305139711,
#  0.8746492476244244,
#  0.8029401224796653,
#  0.7894740167607327,
#  0.5190985000928279,
#  0.8037360513080806,
#  0.5182920982088669,
#  0.7544704549063259,
#  0.6966826942201975,
#  0.6284037568347376,
#  0.8419176207690475,
#  0.901361078932647,
#  0.7638024100658,
#  0.5839558394369692,
#  0.7662343869102487,
#  0.5850815865365647,
#  0.7316192153405345,
#  0.47117145733013316,
#  0.8474221683879875,
#  0.721607463287779,
#  0.6658181206840961,
#  0.4315902163979298,
#  0.8127468858923248,
#  0.6362324021426381,
#  0.4173567044995699,
#  0.7605782186002271,
#  0.8482651648133192,
#  0.6488052333124995,
#  0.7638625598475334,
#  0.8536480691296412,
#  0.24383337516131973,
#  0.8489623708130274,
#  0.5575830766993353,
#  0.7103591202963516,
#  0.598611125598184,
#  0.9238533195984189,
#  0.7813070620243585,
#  0.8438360499997697,
#  0.9231354763832205,
#  0.5728166710366552,
#  0.7186809183767983,
#  0.6382250089240773,
#  0.5057503776609542,
#  0.5895204408334291,
#  0.7843553705571423,
#  0.7850447558651039,
#  0.7370404273005858,
#  0.716384375001307,
#  0.6598850343330309,
#  0.3250991161502802,
#  0.7575704267178879,
#  0.6144174569707866,
#  0.8689922216799255,
#  0.8210458870667096,
#  0.792504447569631,
#  0.8462280585468062,
#  0.838597165928219,
#  0.8421614046922016,
#  0.8166502214030904,
#  0.46335673352573015,
#  0.8065601891721496,
#  0.553462914713059,
#  0.8585724636103865,
#  0.6240700598633444,
#  0.7271708094016986,
#  0.5535007563589245,
#  0.5490117595383557,
#  0.6903967782907332,
#  0.808429272465371,
#  0.9120268503148169,
#  0.5865759170994891,
#  0.3913891261258775,
#  0.5310491227380381,
#  0.6688800705048662,
#  0.866830524001707,
#  0.6692277477808461,
#  0.8459910532617713,
#  0.3516988753441584,
#  0.6744131314381405,
#  0.7875939721154036,
#  0.7003909623933101,
#  0.7880101116695557,
#  0.7766402571448,
#  0.7451607832734761,
#  0.6569191918283391,
#  0.32777742564543305,
#  0.848335037831366,
#  0.7766719359497729,
#  0.7309477725298773,
#  0.17812737814900254,
#  0.6064387091237537,
#  0.34761475619368726,
#  0.686932420475432,
#  0.6522160222792546,
#  0.06380115720898746,
#  0.5641261202934463,
#  0.46635484932817467,
#  0.8434331116265676,
#  0.8024552012565146,
#  0.8822604752818449,
#  0.8234724971972717,
#  0.6422793479457812,
#  0.5562943867469138,
#  0.7523144481265578,
#  0.90987093133362,
#  0.688138972153412]

# %%
# plot the molecule alongside its QED score
import matplotlib.pyplot as plt
import numpy as np

# Plot the average qed with a red dotted line
avg_qed = np.mean(qed_scores)
fig, ax = plt.subplots()
ax.barh(np.arange(len(generated_smiles)), qed_scores)
ax.axvline(avg_qed, color='r', linestyle='--')

# plot line for minimum
ax.axvline(min(qed_scores), color='g', linestyle='--')

# plot line for maximum
ax.axvline(max(qed_scores), color='b', linestyle='--')

ax.set_xlabel('QED Score')
ax.set_ylabel('Molecule')
ax.set_title('QED Score for Generated Molecules')
plt.show()

# %%
# Isolate the molecules with the top QED scores
top_molecules = [s for s, q in zip(generated_smiles, qed_scores) if q > 0.8]

# Display the top molecules
dm.to_image(top_molecules, mol_size=(350, 200))

# %%
# Isolate the molecules with the lowest QED scores
low_molecules = [s for s, q in zip(generated_smiles, qed_scores) if q < 0.3]

# Display the low molecules
dm.to_image(low_molecules, mol_size=(350, 200))

# %% [markdown]
# ## Scaffold Decoration - constraint of particular scaffold

# %%
# Example smile and safe strings from dataset
smile = zinc_df_small['smiles'][3]
safe = zinc_df_small['safe'][3]
smile, safe
# Out:
# ('CCOC(=O)[C@@H]1CCCN(C(=O)c2nc(-c3ccc(C)cc3)n3c2CCCCC3)C1',
#  'c15nc%16n2c1C%17%30C%14%32C%44%22C%26%13C2%41%12.[C@]1%28%35C7%36N%19C%27%39C%42%33C1%43%31.c1%16c%23c6c9c%38c1%29.C48%18%24.C%40%10%18%20.C%379%11%25.C=%15%28%34.C5%19=%21.O%20%34.O=%15.O=%21.[H]4.[H]%24.[H]8.[H]%10.[H]%40.[H]%35.[H]%43.[H]%31.[H]%42.[H]%33.[H]%39.[H]%27.[H]%29.[H]%38.[H]%25.[H]%11.[H]%37.[H]6.[H]%23.[H]%30.[H]%17.[H]%32.[H]%14.[H]%22.[H]%44.[H]%13.[H]%26.[H]%12.[H]%41.[H]7.[H]%36')

# %%
safe = sf.encode(smile)
safe
# Out:
# 'c17nc9n2c1CCCCC2.[C@@H]18CCCN5C1.c19ccc(C)cc1.C48=O.C57=O.CC6.O46'

# %%
scaffold = "[*]N-c1ccc2ncnc(-N[*])c2c1"

dm.to_image(scaffold)

# %%
generated_smiles = designer.scaffold_decoration(
    scaffold=scaffold,
    n_samples_per_trial=12,
    n_trials=2,
    sanitize=True,
    do_not_fragment_further=True,
)

generated_mols = [dm.to_mol(x) for x in generated_smiles]
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/transformers/generation/configuration_utils.py:433: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# 2024-02-28 13:56:59.364 | INFO     | safe.sample:scaffold_decoration:538 - After sanitization, 22 / 24 (91.67 %)  generated molecules are valid !

# %%
dm.viz.lasso_highlight_image(generated_mols[:12], dm.from_smarts(scaffold), mol_size=(350, 200), color_list=["#ff80b5"], scale_padding=0.1)

# %% [markdown]
# ## Super structure generation - constraint of particular super structure

# %%
superstructure = "c1ccc2ncncc2c1"

dm.to_image(superstructure)

# %%
generated_smiles = designer.super_structure(
    core=superstructure,
    n_samples_per_trial=12,
    n_trials=1,
    sanitize=True,
    do_not_fragment_further=False,
    attachment_point_depth=3,
)

generated_smiles
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 2024-02-28 13:57:00.757 | INFO     | safe.sample:super_structure:492 - After sanitization, 12 / 12 (100.00 %)  generated molecules are valid !
# ['O=C([O-])c1ncc2ccccc2n1',
#  'O=C([O-])C(=O)CCCSc1ncc2ccccc2n1',
#  'O=C([O-])C[C@H](NC(=O)c1ncc2ccccc2n1)C(=O)[O-]',
#  'N[C@H](C(=O)Nc1ncc2ccccc2n1)C(F)(F)F',
#  'N#CCCCC(=O)Nc1ncc2ccccc2n1',
#  'FC(F)(F)Oc1ncc2ccccc2n1',
#  'N#Cc1ccncc1-c1ncc2ccccc2n1',
#  'OC[C@@H](CC(F)(F)F)Nc1ncc2ccccc2n1',
#  'O=C(NCCCS)Nc1ncc2ccccc2n1',
#  'OCc1ncc2ccccc2n1',
#  'O=C(CC=Nc1ncc2ccccc2n1)C(F)(F)F',
#  'O[C@H](CNc1ncc2ccccc2n1)CC(F)(F)F']

# %%
dm.to_image(generated_smiles[:12], mol_size=(350, 200))

# %% [markdown]
# ## Motif Extension - constraint of particular motif

# %%
motif = "[*]-N1CCCCC1"

dm.to_image(motif)

# %%
# let's make some long sequence
generated_smiles = designer.motif_extension(
    motif=motif,
    n_samples_per_trial=12,
    n_trials=1,
    sanitize=True,
    do_not_fragment_further=False,
    min_length=25,
    max_length=80,
)

generated_smiles
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 2024-02-28 13:57:04.551 | INFO     | safe.sample:scaffold_decoration:538 - After sanitization, 12 / 12 (100.00 %)  generated molecules are valid !
# ['N#CCCCCS(=O)(=O)NCCC(=O)N1CCCCC1',
#  'O=C([O-])CSCC(=O)NCCC(=O)N1CCCCC1',
#  'O=C([O-])CSCC(=O)OCC(=O)N1CCCCC1',
#  'O=C(CCC(=O)N1CCCCC1)NC[C@H](O)C(F)F',
#  'O=C(NCC(=O)N1CCCCC1)NC[C@@H](O)C(F)F',
#  'NC(=O)CCCCCC(=O)N1CCCCC1',
#  'O=C(N1CCCCC1)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)F',
#  'CCCC.FC(F)=CCN1CCCCC1',
#  'O=C([O-])CC[NH+](CC(=O)[O-])CC(=O)N1CCCCC1',
#  'BrCCCCCCCCCOCCCCCCCCCN1CCCCC1',
#  'O=C(CS(=O)(=O)CCC(F)(F)C(F)(F)F)N1CCCCC1',
#  'O=C(NCCOCCF)NCC(=O)N1CCCCC1']

# %%
dm.to_image(generated_smiles[:12], mol_size=(350, 200))

# %% [markdown]
# ## Scaffold Hopping - constraint of particular scaffold

# %%
side_chains = "[1*]C(=O)C#CCN1CCCCC1.[2*]c1cccc(Br)c1"

dm.to_image(side_chains)

# %%
generated_smiles = designer.scaffold_morphing(
    side_chains=side_chains,
    n_samples_per_trial=12,
    n_trials=1,
    sanitize=True,
    do_not_fragment_further=False,
    random_seed=100,
)

dm.to_image(generated_smiles[:12], mol_size=(350, 200))
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 2024-02-28 13:57:16.820 | INFO     | safe.sample:_fragment_linking:393 - After sanitization, 12 / 12 (100.00 %)  generated molecules are valid !

# %% [markdown]
# ## Linker generation - constraint of particular linker

# %%
linker_generation = ["[*]-N1CCCCC1", "Brc1cccc(Nc2ncnc3ccc(-[*])cc23)c1"]

dm.to_image(linker_generation)

# %%
generated_smiles = designer.linker_generation(
    *linker_generation,
    n_samples_per_trial=12,
    n_trials=1,
    sanitize=True,
    do_not_fragment_further=False,
    random_seed=100,
)

generated_smiles
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 2024-02-28 13:57:20.030 | INFO     | safe.sample:_fragment_linking:393 - After sanitization, 12 / 12 (100.00 %)  generated molecules are valid !
# ['Brc1cccc(Nc2ncnc3ccc(-c4nc5c(N6CCCCC6)ccnc5[nH]4)cc23)c1',
#  'Brc1cccc(Nc2ncnc3ccc(-c4ccnc5[nH]c(N6CCCCC6)nc45)cc23)c1',
#  'Brc1cccc(Nc2ncnc3ccc(-c4nc(N5CCCCC5)c5ccsc5n4)cc23)c1',
#  'Brc1cccc(Nc2ncnc3ccc(-c4nc(N5CCCCC5)nc5sccc45)cc23)c1',
#  'Brc1cccc(Nc2ncnc3ccc(N=C4S[C@@H]5CNC[C@H]5N4N=CN4CCCCC4)cc23)c1',
#  'Brc1cccc(Nc2ncnc3ccc(C=NN4C(=NN5CCCCC5)S[C@@H]5CNC[C@H]54)cc23)c1',
#  'O=c1c2cc3ccccc3cc2c(N2CCCCC2)nn1-c1ccc2ncnc(Nc3cccc(Br)c3)c2c1',
#  'O=c1c2cc3ccccc3cc2c(-c2ccc3ncnc(Nc4cccc(Br)c4)c3c2)nn1N1CCCCC1',
#  'O=S1(=O)C2(N3CCCCC3)SCCCN2C1(c1ccc2ncnc(Nc3cccc(Br)c3)c2c1)N1CCOCC1',
#  'O=S1(=O)C2(c3ccc4ncnc(Nc5cccc(Br)c5)c4c3)SCCCN2C1(N1CCCCC1)N1CCOCC1',
#  'Brc1cccc(Nc2ncnc3ccc(C=CN4CCCCC4)cc23)c1',
#  'Brc1cccc(Nc2ncnc3ccc(C=CN4CCCCC4)cc23)c1']

# %%
dm.to_image(generated_smiles[:12], mol_size=(350, 200))
