# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="google/recurrentgemma-2b-it")
# pipe = pipeline("text-generation", model="gpt2")
# pipe = pipeline("text-generation", model="apple/OpenELM-270M", trust_remote_code=True)
# Out:
# model.safetensors.index.json:   0%|          | 0.00/42.8k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 # Use a pipeline as a high-level helper
#       2 from transformers import pipeline
# ----> 4 pipe = pipeline("text-generation", model="google/recurrentgemma-2b-it")
#       5 # pipe = pipeline("text-generation", model="gpt2")
#       6 # pipe = pipeline("text-generation", model="apple/OpenELM-270M", trust_remote_code=True)
#
# ...
