# %%
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
# Read the JSON file
with open('checkpoint-5000/trainer_state.json', 'r') as file:
    data = json.load(file)

# %%
# Extract epoch and loss data from log_history
epochs = []
losses = []
for entry in data['log_history'][:-1]:
    epochs.append(entry['step'])
    losses.append(entry['train_loss'])

# %%
# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(epochs, losses)
plt.title('Training Loss over Steps')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.grid(True)
plt.savefig('training_convergence.png')
